# %% [markdown]
# ## Linux Assignment
#
#
# 1.   What is Linux ?
#
#
# *   Linux is a Operating system like Windows which manages computer harware and software
#
#
#
# 2.    What is the difference between Hard Link & Soft Link?
#
#
# *   Hard link is direct pointer to the file
#
#
# *   Soft link is shorcut or path to another file
#
#
# 3.   What is a Kernel in Linux ?
#
#
# *   Kernel is the core part of the Linux and it connects the software to hardware, allocates memory.
#
# 4.   How do you create a user account ?
#
#
# *   as i am using Linux in Windows machine i used to create with
# git config --global user.name  "Sridhar"
# git config --global user.email "Sridharp048@gmail.com"
#
# 5.   What is the ‘grep’ command used for in Linux ?
# *   grep used to search the word we give inside the file or in output of the file.

# %%
#6.I Step1: Create user p1
sudo add  user p1
 #Step2: He should be part of 3 groups g1,g2,g3.
 sudo groupadd g1
  sudo useradd -m -s /bin/bash/ -G  p1
 #Step3: whenever he creates a file automatically in the group section of file grp g1 should come
sudo usermod -g g1 p1
# Out:
#   File "<ipython-input-1-495830105>", line 2
#     sudo add  user p1
#          ^
# SyntaxError: invalid syntax

# %%
#7.Step1: Create directory /tmp/bg as root user and create files inside it.
sudo mkdir /tmp/bg
#Step2: “abhi” should be the owner of the directory. He should be able to create files and delete files inside the directory and also he should be able to add content to all files inside the di
sudo add user abhi
sudo chown abhi/tmp/bg

# %% [markdown]
# 8.You suspect that a particular process is consuming excessive CPU resources on your Linux server. How
# would you identify and terminate this process?
#
#
# * top
#
#
# *   sudo kill PID
